# %% [markdown]
# ## This is my first attempt at cleaning the data we have for this project.
# This is a learning process and it is very likely I may do things that end up being unnecessary or at worst totally wrong. _Ikenna_

# %%
import pandas as pd
import numpy as np

# %%
Hint_raw_data = pd.read_csv("../Data/HINTS_erdos.csv")

# %% [markdown]
# Looking at information about data

# %%
Hint_raw_data.head()
# Initial look
# Out:
#        HHID     PERSONID Stratum APP_REGION  HIGHSPANLI  HISPSURNAME  HISP_HH  \
# 0  20000035  20000035-01      HM        NaN           2            2        2
# 1  20000044  20000044-01      LM        NaN           2            2        2
# 2  20000080  20000080-01      HM        NaN           2            2        2
# 3  20000101  20000101-01      HM        NaN           2            2        2
# 4  20000165  20000165-01      HM        NaN           2            2        2
#
#    Treatment_C2  RUC2003  CENSDIV  ...  EducA  EducB  RaceEthn  HHInc   BMI  \
# 0             1        1        5  ...      3      3         2      5  29.0
# 1             1        6        2  ...      2      2         2     -9  27.3
# 2             1        1        3  ...      4      4         5      5  20.4
# 3             1        1        5  ...      4      5         3      5  22.1
# 4             1        4        5  ...     -9     -9         2      3  28.9
#
# ...

# %%
# See column labels or variables or features
Col_names = list(Hint_raw_data.columns)
Col_names
# Out:
# ['HHID',
#  'PERSONID',
#  'Stratum',
#  'APP_REGION',
#  'HIGHSPANLI',
#  'HISPSURNAME',
#  'HISP_HH',
#  'Treatment_C2',
#  'RUC2003',
#  'CENSDIV',
#  'CENSREG',
#  'FormType',
#  'Language_Flag',
#  'QDisp',
#  'AdultsInHH',
#  'MailHHAdults',
#  'SeekHealthInfo',
#  'WhereSeekHealthInfo',
#  'WhereSeekHealthInfo_OS',
#  'LookElsewhere',
#  'WhoLookingFor',
#  'SeekCancerInfo',
#  'CancerLotOfEffort',
#  'CancerFrustrated',
#  'CancerConcernedQuality',
#  'CancerTooHardUnderstand',
#  'CancerConfidentGetHealthInf',
#  'CancerTrustDoctor',
#  'CancerTrustFamily',
#  'CancerTrustNewsMag',
#  'CancerTrustRadio',
#  'CancerTrustInternet',
#  'CancerTrustTelevision',
#  'CancerTrustGov',
#  'CancerTrustCharities',
#  'CancerTrustReligiousOrgs',
#  'StrongNeedCancerInfo',
#  'StrongNeedCancerInfo_OS',
#  'CancerAttention_OnlineNews',
#  'CancerAttention_PrintNews',
#  'CancerAttention_HealthNews',
#  'CancerAttention_Internet',
#  'CancerAttention_Radio',
#  'CancerAttention_LocalTV',
# ...

# %%
# Get little information on missing values
print("Missing values distribution")
print(Hint_raw_data.isnull().mean())
print("")
# Out:
# Missing values distribution
# HHID                0.00000
# PERSONID            0.00000
# Stratum             0.00000
# APP_REGION          0.92865
# HIGHSPANLI          0.00000
#                      ...
# AgeDX               0.00000
# TimeSinceDX         0.00000
# smokeStat           0.00000
# PHQ4                0.00000
# IncomeRanges_IMP    0.00000
# Length: 357, dtype: float64

# %%
Hint_raw_data.describe
# Out:
# <bound method NDFrame.describe of           HHID     PERSONID Stratum APP_REGION  HIGHSPANLI  HISPSURNAME  \
# 0     20000035  20000035-01      HM        NaN           2            2
# 1     20000044  20000044-01      LM        NaN           2            2
# 2     20000080  20000080-01      HM        NaN           2            2
# 3     20000101  20000101-01      HM        NaN           2            2
# 4     20000165  20000165-01      HM        NaN           2            2
# ...        ...          ...     ...        ...         ...          ...
# 3625  20120438  20120438-02      LM        NaN           2            2
# 3626  20120465  20120465-01      HM        NaN           2            2
# 3627  20120504  20120504-02      LM        NaN           2            2
# 3628  20120522  20120522-01      HM        NaN           2            2
# 3629  20120531  20120531-01      HM        NaN           2            2
#
# ...

# %%
# Check data types in columns
print("Column Data Types:")
print(Hint_raw_data.dtypes)

## Looks like they are mostly int64
# Objects are either strings or mixed types
# Out:
# Column Data Types:
# HHID                 int64
# PERSONID            object
# Stratum             object
# APP_REGION          object
# HIGHSPANLI           int64
#                      ...
# AgeDX                int64
# TimeSinceDX          int64
# smokeStat            int64
# PHQ4                 int64
# IncomeRanges_IMP     int64
# Length: 357, dtype: object

# %%
Hint_raw_data.lt(0).sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Hint_raw_data.lt(0).sum()
#
# File /opt/anaconda3/envs/erdos_may_2024/lib/python3.11/site-packages/pandas/core/frame.py:8335, in DataFrame.lt(self, other, axis, level)
#    8333 @Appender(ops.make_flex_doc("lt", "dataframe"))
#    8334 def lt(self, other, axis: Axis = "columns", level=None) -> DataFrame:
# -> 8335     return self._flex_cmp_method(other, operator.lt, axis=axis, level=level)
#
# File /opt/anaconda3/envs/erdos_may_2024/lib/python3.11/site-packages/pandas/core/frame.py:8318, in DataFrame._flex_cmp_method(self, other, op, axis, level)
#    8314 axis = self._get_axis_number(axis) if axis is not None else 1
#    8316 self, other = self._align_for_op(other, axis, flex=True, level=level)
# -> 8318 new_data = self._dispatch_frame_op(other, op, axis=axis)
# ...

# %% [markdown]
# ## Now turn attention to particular variables since it has become difficult to work with all the data.

# %%
#"APP_REGION",
df = Hint_raw_data[["CENSDIV","CENSREG","Cancer_Cat","AgeDX","AgeGrpA","AgeGrpB","EverHadCancer","FamilyEverHadCancer","WhenDiagnosedCancer"]]

# %%
df.head
# Out:
# <bound method NDFrame.head of      APP_REGION  CENSDIV  CENSREG  Cancer_Cat  AgeDX  AgeGrpA  AgeGrpB  \
# 0           NaN        5        3          -1     -1        1        1
# 1           NaN        2        1          -1     -1        4        4
# 2           NaN        3        2          -1     -1        1        1
# 3           NaN        5        3          -1     -1        3        2
# 4           NaN        5        3          -1     -1        4        2
# ...         ...      ...      ...         ...    ...      ...      ...
# 3625        NaN        8        4          19     70        4        5
# 3626        NaN        5        3          -1     -1        4        5
# 3627        NaN        2        1          -1     -1        3        2
# 3628        NaN        5        3          -1     -1        1        1
# 3629        NaN        1        1          -1     -1        3        2
#
#       EverHadCancer  FamilyEverHadCancer  WhenDiagnosedCancer
# ...

# %%
# Do some plots
ax =
# Out:
#   Cell In[23], line 2
#     ax =
#          ^
# SyntaxError: invalid syntax
